# %%
from huggingface_hub import snapshot_download
import os

REPO_ID = "FreedomIntelligence/PubMedVision"
OUTPUT_DIR = "/vol/research/fmodel_medical/people/umar/datasets/PubMedVision"

os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"Downloading {REPO_ID} to {OUTPUT_DIR} ...")

snapshot_download(
    repo_id=REPO_ID,
    repo_type="dataset",
    local_dir=OUTPUT_DIR,
    local_dir_use_symlinks=False,  # copy files directly, no symlinks
)

print("Download complete.")
